# %% [markdown]
# # ***Exercise Regression Metrics on Income Dataset***

# %% [markdown]
# ### ✅ Coded by : Himel Sarder
# ### ✅ info.himelcse@gmail.com
# ### ✅ https://www.linkedin.com/in/himel-sarder/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Income.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    income  happiness
# 0           1  3.862647   2.314489
# 1           2  4.979381   3.433490
# 2           3  4.923957   4.599373
# 3           4  3.214372   2.791114
# 4           5  7.196409   5.596398

# %%
df.shape
# Out:
# (498, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  498 non-null    int64
#  1   income      498 non-null    float64
#  2   happiness   498 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
plt.scatter(df['income'], df['happiness'], c=df['happiness'], cmap='coolwarm')
plt.xlabel('Income')
plt.ylabel('Happiness')
plt.colorbar(label='Happiness')

# %%
X = df.iloc[:,1:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
y
# Out:
# 0      2.314489
# 1      3.433490
# 2      4.599373
# 3      2.791114
# 4      5.596398
#          ...
# 493    4.568705
# 494    2.535002
# 495    4.397451
# 496    2.070664
# 497    3.710193
# Name: happiness, Length: 498, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#        income
# 53   5.482862
# 334  2.381385
# 152  3.681486
# 377  4.772059
# 476  5.237893
# ..        ...
# 22   2.428752
# 72   1.506275
# 493  5.249209
# 15   2.559166
# 168  6.143150
#
# [398 rows x 1 columns]

# %%
X_test
# Out:
#        income
# 395  6.195004
# 223  6.377376
# 312  3.614745
# 179  5.189031
# 412  6.768336
# ..        ...
# 491  2.482382
# 393  5.741725
# 120  5.711264
# 364  1.890327
# 188  3.897738
#
# [100 rows x 1 columns]

# %%
y_train
# Out:
# 53     3.857424
# 334    2.176322
# 152    3.036820
# 377    3.554600
# 476    3.342749
#          ...
# 22     1.200786
# 72     1.308487
# 493    4.568705
# 15     2.898583
# 168    4.927133
# Name: happiness, Length: 398, dtype: float64

# %%
y_test
# Out:
# 395    4.058312
# 223    5.079476
# 312    2.901789
# 179    4.767596
# 412    5.910285
#          ...
# 491    0.548365
# 393    3.776485
# 120    3.901170
# 364    2.481624
# 188    2.799747
# Name: happiness, Length: 100, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([4.61136034, 4.74097829, 2.77748749, 3.89638306, 5.01884598,
#        2.78995245, 3.74737829, 1.92079696, 3.24322412, 2.74652107,
#        4.82903679, 4.03196541, 4.75096529, 5.26843318, 1.36246853,
#        3.54044027, 5.50198771, 2.72460611, 5.11024121, 2.62480178,
#        2.92852471, 2.06185697, 1.3287457 , 2.69478754, 4.10653795,
#        5.44235502, 3.58838672, 2.81027453, 2.07727532, 5.40447488,
#        4.20654894, 3.58353872, 3.99275939, 1.68666302, 4.47404893,
#        2.72472211, 3.17676767, 1.5345947 , 2.12310002, 3.41892281,
#        2.70461734, 3.92351182, 3.6443335 , 4.11213195, 4.83539358,
#        3.21540055, 3.17378567, 2.33809548, 4.70033499, 4.26849084,
#        1.30619318, 2.54182414, 1.82494859, 3.51153932, 1.61886511,
#        3.54873896, 2.759206  , 1.40273875, 2.67589075, 4.0504115 ,
#        3.2329332 , 1.28452928, 3.60829093, 3.21018718, 2.65389237,
#        2.88395145, 1.99761435, 1.33813377, 3.80592613, 5.36855314,
# ...

# %%
y_test
# Out:
# 395    4.058312
# 223    5.079476
# 312    2.901789
# 179    4.767596
# 412    5.910285
#          ...
# 491    0.548365
# 393    3.776485
# 120    3.901170
# 364    2.481624
# 188    2.799747
# Name: happiness, Length: 100, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# y_test: actual values
# y_pred: predicted values

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate R-squared (R²)
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.5515786593642154
# Mean Squared Error: 0.4616028153050869
# R-squared: 0.765589266021235

# %%
plt.scatter(df['income'],df['happiness'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Income')
plt.ylabel('Happiness')
# Out:
# Text(0, 0.5, 'Happiness')

# %%
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Squared Error: 0.5174499850077623

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (100, 2)

# %%
print("Adjusted R2 Score : ")
1 - ((1-r2)*(100-1))/(100-1-2)
# Out:
# Adjusted R2 Score :
# 0.8612256302807642

# %%
import pickle

# %%
pickle.dump(lr, open('Mymodel.pkl', 'wb'))

# %% [markdown]
# ### ***Extra : Test code for R2 Score and Adjusted R2 Score changing***

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(498)

new_df1 = new_df1[['income','random_feature','happiness']]
new_df1.head()
# Out:
#      income  random_feature  happiness
# 0  3.862647        0.420151   2.314489
# 1  4.979381        0.699796   3.433490
# 2  4.923957        0.877264   4.599373
# 3  3.214372        0.527513   2.791114
# 4  7.196409        0.645130   5.596398

# %%
plt.scatter(new_df1['random_feature'],new_df1['happiness'])
plt.xlabel('random_feature')
plt.ylabel('Happiness')
# Out:
# Text(0, 0.5, 'Happiness')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X
# Out:
#        income  random_feature
# 0    3.862647        0.312580
# 1    4.979381        0.399101
# 2    4.923957        0.129297
# 3    3.214372        0.232140
# 4    7.196409        0.619390
# ..        ...             ...
# 493  5.249209        0.983382
# 494  3.471799        0.946008
# 495  6.087610        0.981068
# 496  3.440847        0.762425
# 497  4.530545        0.405730
#
# [498 rows x 2 columns]

# %%
y
# Out:
# 0      2.314489
# 1      3.433490
# 2      4.599373
# 3      2.791114
# 4      5.596398
#          ...
# 493    4.568705
# 494    2.535002
# 495    4.397451
# 496    2.070664
# 497    3.710193
# Name: happiness, Length: 498, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([4.61324208, 4.73841838, 2.77961884, 3.90494966, 5.02133401,
#        2.78324714, 3.74999549, 1.90999205, 3.24850717, 2.73799961,
#        4.81981455, 4.02941156, 4.75953027, 5.26609946, 1.37617051,
#        3.52612399, 5.50124434, 2.71999578, 5.10532865, 2.63513538,
#        2.93127955, 2.05416122, 1.32390753, 2.6825738 , 4.10218685,
#        5.45256338, 3.59224736, 2.79582222, 2.09072905, 5.41298045,
#        4.1955898 , 3.57285962, 4.00103009, 1.6947798 , 4.46374393,
#        2.72239149, 3.16684724, 1.54507891, 2.11462952, 3.42111841,
#        2.70156646, 3.92118932, 3.65259529, 4.12193081, 4.8427406 ,
#        3.22327003, 3.18585061, 2.33384904, 4.6993059 , 4.27652279,
#        1.30630757, 2.5298131 , 1.82573761, 3.50360989, 1.61357098,
#        3.53741538, 2.75384964, 1.40497801, 2.66283022, 4.06434855,
#        3.23733653, 1.29002881, 3.62154471, 3.22177262, 2.6461108 ,
#        2.8704471 , 1.98984363, 1.34206698, 3.80493912, 5.35807879,
# ...

# %%
y_test
# Out:
# 395    4.058312
# 223    5.079476
# 312    2.901789
# 179    4.767596
# 412    5.910285
#          ...
# 491    0.548365
# 393    3.776485
# 120    3.901170
# 364    2.481624
# 188    2.799747
# Name: happiness, Length: 100, dtype: float64

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7660372863228345

# %%
X_test.shape
# Out:
# (100, 2)

# %%
1 - ((1-r2)*(100-1)/(100-1-2))
# Out:
# 0.7533906531510959

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['happiness'] + (np.random.randint(-12,12,498)/10)

new_df2 = new_df2[['income','iq','happiness']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 42   5.95  2.44     2.54
# 180  6.19  1.52     2.72
# 38   8.62  5.06     4.36
# 23   6.19  2.38     2.48
# 98   7.69  3.83     3.83

# %%
plt.scatter(new_df2['iq'],new_df2['happiness'])
plt.xlabel('iq')
plt.ylabel('Happiness')
# Out:
# Text(0, 0.5, 'Happiness')

# %%
np.random.randint(-100,100)
# Out:
# 54

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X
# Out:
#        income        iq
# 0    3.862647  1.314489
# 1    4.979381  2.633490
# 2    4.923957  5.699373
# 3    3.214372  2.791114
# 4    7.196409  5.896398
# ..        ...       ...
# 493  5.249209  3.568705
# 494  3.471799  1.835002
# 495  6.087610  4.397451
# 496  3.440847  2.970664
# 497  4.530545  4.210193
#
# [498 rows x 2 columns]

# %%
y
# Out:
# 0      2.314489
# 1      3.433490
# 2      4.599373
# 3      2.791114
# 4      5.596398
#          ...
# 493    4.568705
# 494    2.535002
# 495    4.397451
# 496    2.070664
# 497    3.710193
# Name: happiness, Length: 498, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.8640291529013547

# %%
1 - ((1-r2)*(100-1)/(100-1-2))
# Out:
# 0.8612256302807642

# %% [markdown]
# ## ***Thank You😻***
